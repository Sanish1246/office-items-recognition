# %% [markdown]
# ## Importing Dependencies

# %%
# imports
from ultralytics import YOLO
from pathlib import Path

# %% [markdown]
# ## Define Paths & folder structure

# %%
# data path
DATA_DIR = Path("data/split")

# verify folder structure
assert (DATA_DIR / "train").exists(), "Train folder missing!"
assert (DATA_DIR / "val").exists(), "Validation folder missing!"
assert (DATA_DIR / "test").exists(), "Test folder missing!"

# %% [markdown]
# ## Set up of Yolo dataset config

# %%
yaml_path = Path("office_config.yaml")
if not yaml_path.exists():
    CLASS_NAMES = sorted([p.name for p in (DATA_DIR / "train").iterdir() if p.is_dir()])
    yaml_content = f"""
# YOLOv8 Classification Dataset Config
path: {DATA_DIR}
train: train
val: val
test: test

names:
""" + "\n".join([f"  {i}: {cls}" for i, cls in enumerate(CLASS_NAMES)])
    yaml_path.write_text(yaml_content.strip())
    print(f"{yaml_path} was created successfully")
# Out:
# office_config.yaml was created successfully

# %% [markdown]
# ## Training Model

# %%
# using yolo nano model
model = YOLO("yolov8n-cls.pt")

# train
results = model.train(
    data=str("data/split"),
    epochs=15,
    imgsz=224,     
    batch=32,
    lr0=0.001, 
    project="runs/office_cls",
    name="trial_run_1",
    verbose=True
)
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8n-cls.pt to 'yolov8n-cls.pt': 100% ━━━━━━━━━━━━ 5.3MB 2.8MB/s 1.9s1.9s<0.0s.1s7s
# Ultralytics 8.3.214 🚀 Python-3.11.14 torch-2.9.0 CPU (Apple M4 Pro)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=32, bgr=0.0, box=7.5, cache=False, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=data/split, degrees=0.0, deterministic=True, device=cpu, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=15, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=224, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.001, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8n-cls.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=trial_run_1, nbs=64, nms=False, opset=None, optimize=False, optimizer=auto, overlap_mask=True, patience=100, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=runs/office_cls, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/runs/office_cls/trial_run_1, save_frames=False, save_json=False, save_period=-1, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=classify, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# train: /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/train... found 6946 images in 6 classes ✅
# val: /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/val... found 869 images in 6 classes ✅
# test: /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/test... found 869 images in 6 classes ✅
# Overriding model.yaml nc=1000 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    337926  ultralytics.nn.modules.head.Classify         [256, 6]
# YOLOv8n-cls summary: 56 layers, 1,445,974 parameters, 1,445,974 gradients, 3.4 GFLOPs
# Transferred 156/158 items from pretrained weights
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 112.5±41.0 MB/s, size: 18.1 KB)
# train: Scanning /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/train... 6946 images, 0 corrupt: 100% ━━━━━━━━━━━━ 6946/6946 24.5Mit/s 0.0s
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 105.6±39.2 MB/s, size: 19.9 KB)
# val: Scanning /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/val... 869 images, 0 corrupt: 100% ━━━━━━━━━━━━ 869/869 5.3Mit/s 0.0s0s
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.001' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 26 weight(decay=0.0), 27 weight(decay=0.0005), 27 bias(decay=0.0)
# Image sizes 224 train, 224 val
# Using 0 dataloader workers
# Logging results to /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/runs/office_cls/trial_run_1
# Starting training for 15 epochs...
#
#       Epoch    GPU_mem       loss  Instances       Size
#        1/15         0G       1.16          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:420.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.5s
#                    all      0.792      0.995
#
#       Epoch    GPU_mem       loss  Instances       Size
#        2/15         0G     0.6154          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:421.0sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.5s
#                    all      0.812      0.994
#
#       Epoch    GPU_mem       loss  Instances       Size
#        3/15         0G     0.5727          2        224: 100% ━━━━━━━━━━━━ 218/218 2.2it/s 1:410.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.4s
#                    all      0.847      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        4/15         0G      0.509          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:421.0sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.2it/s 6.5s0.5s
#                    all      0.831          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        5/15         0G     0.4648          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:441.0sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.0s0.4s
#                    all       0.86          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        6/15         0G     0.4258          2        224: 100% ━━━━━━━━━━━━ 218/218 2.2it/s 1:410.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.5s
#                    all      0.871      0.999
#
#       Epoch    GPU_mem       loss  Instances       Size
#        7/15         0G     0.3977          2        224: 100% ━━━━━━━━━━━━ 218/218 2.2it/s 1:410.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all      0.867      0.998
#
#       Epoch    GPU_mem       loss  Instances       Size
#        8/15         0G     0.3646          2        224: 100% ━━━━━━━━━━━━ 218/218 2.2it/s 1:410.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all      0.869          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#        9/15         0G     0.3312          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:430.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all      0.867          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       10/15         0G     0.2994          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:410.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.4s
#                    all      0.873          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       11/15         0G     0.2849          2        224: 100% ━━━━━━━━━━━━ 218/218 2.2it/s 1:410.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all      0.877          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       12/15         0G     0.2735          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:420.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.5s
#                    all      0.876          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       13/15         0G     0.2423          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:420.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all       0.87          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       14/15         0G     0.2362          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:421.0sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all      0.881          1
#
#       Epoch    GPU_mem       loss  Instances       Size
#       15/15         0G     0.2111          2        224: 100% ━━━━━━━━━━━━ 218/218 2.1it/s 1:420.9sss
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.2s0.5s
#                    all       0.88          1
#
# 15 epochs completed in 0.449 hours.
# Optimizer stripped from /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/runs/office_cls/trial_run_1/weights/last.pt, 3.0MB
# Optimizer stripped from /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/runs/office_cls/trial_run_1/weights/best.pt, 3.0MB
#
# Validating /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/runs/office_cls/trial_run_1/weights/best.pt...
# Ultralytics 8.3.214 🚀 Python-3.11.14 torch-2.9.0 CPU (Apple M4 Pro)
# YOLOv8n-cls summary (fused): 30 layers, 1,442,566 parameters, 0 gradients, 3.3 GFLOPs
# train: /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/train... found 6946 images in 6 classes ✅
# val: /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/val... found 869 images in 6 classes ✅
# test: /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/data/split/test... found 869 images in 6 classes ✅
#                classes   top1_acc   top5_acc: 100% ━━━━━━━━━━━━ 14/14 2.3it/s 6.1s0.4s
#                    all      0.881          1
# Speed: 0.0ms preprocess, 6.1ms inference, 0.0ms loss, 0.0ms postprocess per image
# Results saved to /Users/zoulien/Documents/GitHub/office-items-recognition/office-items-prediction/runs/office_cls/trial_run_1
